# %%
#Algoritmo Bhaskara
import math
a=float(input("Digite o valor de a:"))
b=float(input("Digite o valor de b:"))
c=float(input("Digite o valor de c:"))
D=b**2 - 4*a*c
x1= (-(b) + math.sqrt(D))/2*a
x2= (-(b) - math.sqrt(D))/2*a
print(f"Raízes da equação: x1={x1} x2={x2}")
print(f"Valores de entrada: a:{a} b:{b} c:{c}")
# Out:
# Raízes da equação: x1=-1.0 x2=-1.0
# Valores de entrada: a:1.0 b:2.0 c:1.0

# %%
#Algoritmo Bhaskara_2
import math
a=float(input("Digite o valor de a:"))
b=float(input("Digite o valor de b:"))
c=float(input("Digite o valor de c:"))
D=b**2 - 4*a*c
if (D>0):
    x1= (-(b) + math.sqrt(D))/2*a
    x2= (-(b) - math.sqrt(D))/2*a
    print(f"Raízes da equação: x1={x1} x2={x2}")
    print(f"Valores de entrada: a:{a} b:{b} c:{c}")
elif (D==0):
    x1= -b/2*a
    print(f"Raíz da equação: x1={x1}")
    print(f"Valores de entrada: a:{a} b:{b} c:{c}")
else:
    print(f"Não existem raízes reais para a equação")
    print(f"Valores de entrada: a:{a} b:{b} c:{c}")
# Out:
# Não existem raízes reais para a equação
# Valores de entrada: a:1.0 b:2.0 c:9.0

# %%
#Algoritmo SalarioLiquido
SalBruto=float(input("Digite o valor do salário bruto:"))
SalLiq= (SalBruto*0.92) - 22.45
print(f"Salário líquido: {SalLiq}")
# Out:
# Salário líquido: 1817.55

# %%
#Algoritmo SalarioLiquido_2
vendas=float(input("Digite o valor das vendas:"))
Salfixo=998.00
SalBruto=Salfixo + (vendas * 0.05)
SalLiq= (SalBruto*0.92) - 22.45
print(f"Salário líquido: {SalLiq}")
# Out:
# Salário líquido: 1125.71

# %%
#Algoritmo QuantidadeDeDias
import math
ano1=int(input("Digite o ano 1:"))
ano2=int(input("Digite o ano 2:"))
QtdeDias= (ano2 - ano1) * 360
print(f"Quantidade de dias entre {ano1} e {ano2}: {QtdeDias}")
# Out:
# Quantidade de dias entre 2000 e 2020: 7200

# %%
#Algoritmo IMC
peso=float(input("Digite o peso:"))
altura=float(input("Digite a altura:"))
IMC= peso/(altura**2)
print(f"Seu IMC é: {IMC}")
if (IMC<=18.5):
    print("Abaixo do peso")
if (IMC>18.5 and IMC<=25):
    print("Peso normal")
if (IMC>25 and IMC<=30):
    print("Acima do peso")
if (IMC>30):
    print("Obesidade")
# Out:
# Seu IMC é: 26.595000139973685
# Acima do peso

# %%
#Algoritmo Notas
N1=float(input("Digite a nota 1:"))
N2=float(input("Digite a nota 2:"))
N3=float(input("Digite a nota 3:"))
N4=float(input("Digite a nota 4:"))
media= (N1 + N2 + N3 + N4)/4
if (media>=7):
    print(f"Aluno aprovado com média: {media}")
# if (media<7 and media>=5):
#     print(f"Aluno em recuperação com média: {media}")
else:
    print(f"Aluno Reprovado com média: {media}")
# Out:
# Aluno aprovado com média: 8.0

# %%
#Algoritmo Idade
import datetime
AnoNasc=int(input("Digite o ano de nascimento:"))
DataAtual=datetime.datetime.now().year
Idade= DataAtual - AnoNasc
print(f"Sua idade é: {Idade}")

if Idade <16:
    print("Você não pode votar nem dirigir")
elif Idade<=16:
    print("Você pode votar, mas não pode dirigir")
elif Idade>=18 and Idade<70:
    print("Você pode votar e dirigir")
else:
    print("Você pode votar, mas não pode dirigir")
# Out:
# Sua idade é: 17
# Você pode votar, mas não pode dirigir

# %%
#Algoritmo Triangulo
A=int(input("Digite o valor do lado A:"))
B=int(input("Digite o valor do lado B:"))
C=int(input("Digite o valor do lado C:"))
if (A != 0) and (B != 0) and (C != 0):
    if (A < B + C) and (B < A + C) and (C < A + B):
        if (A == B) and (B == C):
            print("Triângulo Equilátero")
        elif (A == B) or (B == C) or (A == C):
            print("Triângulo Isósceles")
        else:
            print("Triângulo Escaleno")
    else:
        print("Os lados não formam um triângulo")
else:
    print("Os lados não formam um triângulo")
# Out:
# Triângulo Escaleno

# %%
# Algoritmo Produto
# From unittest import case  # ❌ Este import não é necessário aqui.
# O módulo 'unittest' é usado para testes automatizados em Python.
# Dentro dele existe uma função chamada 'case', mas ela não tem relação com o comando 'case' do 'match'.
# O 'match/case' é uma estrutura de controle nativa da linguagem, não precisa ser importada.
# Portanto, esta linha pode ser removida.

codigo = input("Digite o código do produto:")  # Solicita ao usuário o código do produto.

match codigo:  # Inicia uma estrutura de correspondência de padrões (pattern matching).
    case "1":  # Se o valor digitado for "1" (string), executa este bloco.
        print("Produto: Caderno")
    case "2":  # Se o valor for "2", executa este bloco.
        print("Produto: Lápis")
    case "3":  # Se o valor for "3", executa este bloco.
        print("Produto: Borracha")
    case _:  # O sublinhado (_) é o "default" — cobre qualquer outro valor.
        print("Diversos")
# Out:
# Diversos

# %%
#Algoritmo Produto_2
codigo = int(input("Digite o código do produto:"))
match codigo:
    case 1:
        print("Classificação: Alimento não perecível")   
    case 2| 3| 4:
        print("Classificação: Alimento perecível")
    case 5| 6:
        print("Classificação: Vestuário")
    case 7:
        print("Classificação: Higiene pessoal")
    case cod if cod >= 8 and cod <= 15:
        print("Classificação: Limpeza e utensílios domésticos")
    case _:
        print("Classificação: Código inválido")
# Out:
# Classificação: Outros produtos
